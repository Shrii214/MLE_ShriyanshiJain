# %% [markdown]
# 1. Loading the Dataset
# Load the dataset into a Pandas DataFrame.
# Display the first five rows and check for missing values.
# Print the summary statistics of numerical features.
# 2. Exploratory Data Analysis (EDA)
# Identify the number of unique car names and their distribution.
# Visualize the distribution of selling_price and km_driven using histograms.
# Perform correlation analysis among numerical features and visualize it using a heatmap.
# Find the top 5 most frequently occurring car brands in the dataset.
# 3. Data Preprocessing
# Convert categorical variables (fuel, seller_type, transmission, Owner) into numerical form using one-hot encoding or label encoding.
# Handle missing values if any exist in the dataset.
# 4. Regression Analysis
# Define the selling_price as the target variable and select appropriate numerical features as independent variables.
# Perform a train-test split (80-20 ratio) and define X_train, X_test, y_train, y_test.
# Train a Linear Regression Model and evaluate its performance using Mean Absolute Error (MAE) and Root Mean Squared Error (RMSE).
# Interpret the coefficients of the regression model.
# 5. Data Scaling
# Apply MinMax Scaling or Standard Scaling to numerical features and observe the differences.
# Compare model performance with and without feature scaling.
# 6. Polynomial Regression
# Apply Polynomial Regression (degree = 2,3,4) and observe how the model performance changes.
# Plot the actual vs. predicted values for each degree.
# 7. Cross-Validation
# Implement k-fold cross-validation (k=5) and compare its performance with a single train-test split.
# Determine the optimal degree of polynomial regression using cross-validation scores.
# 8. Model Improvement and Interpretation
# Try using Lasso or Ridge Regression to prevent overfitting.
# Compare their performance with the original Linear Regression model.

# %% [markdown]
# Link to dataset: https://www.kaggle.com/datasets/nehalbirla/vehicle-dataset-from-cardekho/data?select=CAR+DETAILS+FROM+CAR+DEKHO.csv
